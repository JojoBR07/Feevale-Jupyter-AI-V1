# %% [markdown]
# # Experimento: Classificador de Diabetes

# %% [markdown]
# ## Acesso e análise dos dados

# %% [markdown]
# Vamos utilizar a biblioteca https://pandas.pydata.org/ para manipulação dos dados.

# %%
import pandas as pd

# %% [markdown]
# A função __[pd.read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)__ Retorna um Dataframe para manipulação dos dados.

# %%
dataset = pd.read_csv('https://github.com/JojoBR07/Feevale-Jupyter-AI-V1/raw/refs/heads/main/diabetes_data_upload.csv'); 
dataset
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 0               No              No     Yes           No             Yes
# 1               No             Yes      No           No              No
# 2               No              No     Yes           No             Yes
# 3              Yes              No     Yes           No             Yes
# 4               No             Yes     Yes          Yes             Yes
# ..             ...             ...     ...          ...             ...
# 515             No              No     Yes           No             Yes
# 516             No              No     Yes          Yes             Yes
# 517             No             Yes      No           No              No
# 518             No             Yes     Yes           No             Yes
# 519             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 0                No              Yes      Yes     Yes  Positive
# 1               Yes               No      Yes      No  Positive
# 2                No              Yes      Yes      No  Positive
# 3                No               No       No      No  Positive
# 4               Yes              Yes      Yes     Yes  Positive
# ..              ...              ...      ...     ...       ...
# 515             Yes               No       No      No  Positive
# 516             Yes               No       No      No  Positive
# 517             Yes              Yes       No     Yes  Positive
# 518              No               No      Yes      No  Negative
# 519              No               No       No      No  Negative
#
# [520 rows x 17 columns]

# %% [markdown]
# <br>
# Veja como os dados carregados foram interpretados ...

# %%
dataset.dtypes
# Out:
# Age                    int64
# Gender                object
# Polyuria              object
# Polydipsia            object
# sudden weight loss    object
# weakness              object
# Polyphagia            object
# Genital thrush        object
# visual blurring       object
# Itching               object
# Irritability          object
# delayed healing       object
# partial paresis       object
# muscle stiffness      object
# Alopecia              object
# Obesity               object
# class                 object
# dtype: object

# %% [markdown]
# <br>
# Uma primeira análise dos dados númericos, como contagem, desvio padrão, entre outros. Apenas os atributos numéricos fazem parte dessa descrição. Lembre que a notação é Americana, portanto o ponto representa vírgula.

# %%
dataset.describe()
# Out:
#               Age
# count  520.000000
# mean    48.028846
# std     12.151466
# min     16.000000
# 25%     39.000000
# 50%     47.500000
# 75%     57.000000
# max     90.000000

# %% [markdown]
# <br>
# Se for necessário, é possível analisar apenas um dos atributos.

# %%
dataset['Age'].mean()
# Out:
# np.float64(48.02884615384615)

# %% [markdown]
# <br>
# Boxplot gerado com base nos dados numéricos do dataset: temperatura e humidade.<br>As colunas dividem os valores em Quartis (P25 = 25%, P50 = 50%, P75 = 75%)

# %%
import matplotlib.pyplot as plt
dataset.boxplot()
plt.show()

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# ### Enconding
# Alguns classificadores não aceitam features com valores nominais, então é necessário fazer o enconding em valores binários.
# É o caso do classificador que será empregado mais adiante.<br>
# __[pd.get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)__ converte variáveis categóricas em variáveis binárias. O atributo ***drop_first=True*** produz apenas uma serie / coluna para atributos que possuem apenas dois valores.

# %%
one_hot_dataset = pd.get_dummies(dataset,drop_first=True)
one_hot_dataset
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes  \
# 0     40         True         False            True                   False
# 1     58         True         False           False                   False
# 2     41         True          True           False                   False
# 3     45         True         False           False                    True
# 4     60         True          True            True                    True
# ..   ...          ...           ...             ...                     ...
# 515   39        False          True            True                    True
# 516   48        False          True            True                    True
# 517   58        False          True            True                    True
# 518   32        False         False           False                   False
# 519   42         True         False           False                   False
#
#      weakness_Yes  Polyphagia_Yes  Genital thrush_Yes  visual blurring_Yes  \
# 0            True           False               False                False
# 1            True           False               False                 True
# 2            True            True               False                False
# 3            True            True                True                False
# 4            True            True               False                 True
# ..            ...             ...                 ...                  ...
# 515         False            True               False                False
# 516          True            True               False                False
# 517          True            True               False                 True
# 518          True           False               False                 True
# 519         False           False               False                False
#
#      Itching_Yes  Irritability_Yes  delayed healing_Yes  partial paresis_Yes  \
# 0           True             False                 True                False
# 1          False             False                False                 True
# 2           True             False                 True                False
# 3           True             False                 True                False
# 4           True              True                 True                 True
# ..           ...               ...                  ...                  ...
# 515         True             False                 True                 True
# 516         True              True                 True                 True
# 517        False             False                False                 True
# 518         True             False                 True                False
# 519        False             False                False                False
#
#      muscle stiffness_Yes  Alopecia_Yes  Obesity_Yes  class_Positive
# 0                    True          True         True            True
# 1                   False          True        False            True
# 2                    True          True        False            True
# 3                   False         False        False            True
# 4                    True          True         True            True
# ..                    ...           ...          ...             ...
# 515                 False         False        False            True
# 516                 False         False        False            True
# 517                  True         False         True            True
# 518                 False          True        False           False
# 519                 False         False        False           False
#
# [520 rows x 17 columns]

# %% [markdown]
# <br>
# <i>X<i> representa exemplos de casos (dias) e seus atributos, mas removendo o atributo classe.

# %%
X = one_hot_dataset[one_hot_dataset.columns[:5]] 
X
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes
# 0     40         True         False            True                   False
# 1     58         True         False           False                   False
# 2     41         True          True           False                   False
# 3     45         True         False           False                    True
# 4     60         True          True            True                    True
# ..   ...          ...           ...             ...                     ...
# 515   39        False          True            True                    True
# 516   48        False          True            True                    True
# 517   58        False          True            True                    True
# 518   32        False         False           False                   False
# 519   42         True         False           False                   False
#
# [520 rows x 5 columns]

# %% [markdown]
# <br><i>y</i> representa a série dos valores classe de cada exemplo.

# %%
y = one_hot_dataset['class_Positive'] 
y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 515     True
# 516     True
# 517     True
# 518    False
# 519    False
# Name: class_Positive, Length: 520, dtype: bool

# %% [markdown]
# ### Separação em Treino e Teste
# A função __[train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)__ extrai um conjunto aleatório de 70% para treino and 30% para teste.
# Uma questão interessante é utilizar o parâmetro *random_state* com um valor fixo inteiro, como por exemplo __[42](https://en.wikipedia.org/wiki/Phrases_from_The_Hitchhiker%27s_Guide_to_the_Galaxy#The_Answer_to_the_Ultimate_Question_of_Life,_the_Universe,_and_Everything_is_42)__. Desta forma, durante o desenvolvimento, a saída do split será sempre a mesma, de forma que é possível avaliar o pipe e seus resultados de forma contínua com os mesmos dados. Quando o pipe estiver em produção, trocamos o parâmetro *random_state* para *None*.

# %%
# Importando biblioteca de separação de treino / teste
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42)

# %%
X_train
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes
# 225   29         True         False           False                   False
# 94    36        False          True            True                   False
# 462   57         True         False           False                   False
# 284   72         True          True           False                   False
# 23    48         True         False            True                    True
# ..   ...          ...           ...             ...                     ...
# 71    35        False         False            True                    True
# 106   58         True         False            True                    True
# 270   40        False          True            True                    True
# 435   57         True          True            True                    True
# 102   90        False         False            True                    True
#
# [364 rows x 5 columns]

# %% [markdown]
# ## Processamento

# %% [markdown]
# ### Treinamento
# Este treinamento produz um modelo de classificador supervisionado baseado no algoritmo de Árvore de Decisão.
# Um exemplo complementar da biblioteca scikit-learn pode ser encontrado em https://scikit-learn.org/stable/modules/tree.html#classification

# %%
from sklearn.tree import DecisionTreeClassifier # Importando classificador
# Cria o objeto de um classificador de Árvores de Decisão
clf = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=1)
# Executa o treinamento (fit)
clf = clf.fit(X_train,y_train)

# %% [markdown]
# Como resultado do aprendizado, obtemos a seguinte árvore:

# %%
from sklearn import tree
tree.plot_tree(clf,rounded=True,feature_names=X.columns,fontsize=6,class_names=['va','nao_va'],proportion=True, impurity=False, filled=True, label='all')
# Out:
# [Text(0.6642361111111111, 0.9583333333333334, 'Polyuria_Yes <= 0.5\nsamples = 100.0%\nvalue = [0.401, 0.599]\nclass = nao_va'),
#  Text(0.3951388888888889, 0.875, 'Gender_Male <= 0.5\nsamples = 51.4%\nvalue = [0.722, 0.278]\nclass = va'),
#  Text(0.5296875, 0.9166666666666667, 'True  '),
#  Text(0.2388888888888889, 0.7916666666666666, 'sudden weight loss_Yes <= 0.5\nsamples = 12.1%\nvalue = [0.318, 0.682]\nclass = nao_va'),
#  Text(0.16666666666666666, 0.7083333333333334, 'Age <= 47.5\nsamples = 7.7%\nvalue = [0.464, 0.536]\nclass = nao_va'),
#  Text(0.08888888888888889, 0.625, 'Age <= 34.5\nsamples = 4.7%\nvalue = [0.294, 0.706]\nclass = nao_va'),
#  Text(0.044444444444444446, 0.5416666666666666, 'Age <= 30.0\nsamples = 2.2%\nvalue = [0.5, 0.5]\nclass = va'),
#  Text(0.022222222222222223, 0.4583333333333333, 'samples = 1.4%\nvalue = [0.2, 0.8]\nclass = nao_va'),
#  Text(0.06666666666666667, 0.4583333333333333, 'samples = 0.8%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.13333333333333333, 0.5416666666666666, 'Age <= 35.5\nsamples = 2.5%\nvalue = [0.111, 0.889]\nclass = nao_va'),
#  Text(0.1111111111111111, 0.4583333333333333, 'samples = 1.4%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.15555555555555556, 0.4583333333333333, 'Age <= 40.5\nsamples = 1.1%\nvalue = [0.25, 0.75]\nclass = nao_va'),
#  Text(0.13333333333333333, 0.375, 'samples = 0.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.17777777777777778, 0.375, 'samples = 0.8%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.24444444444444444, 0.625, 'Polydipsia_Yes <= 0.5\nsamples = 3.0%\nvalue = [0.727, 0.273]\nclass = va'),
#  Text(0.2222222222222222, 0.5416666666666666, 'Age <= 50.5\nsamples = 2.7%\nvalue = [0.8, 0.2]\nclass = va'),
#  Text(0.2, 0.4583333333333333, 'samples = 0.8%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.24444444444444444, 0.4583333333333333, 'Age <= 53.0\nsamples = 1.9%\nvalue = [0.714, 0.286]\nclass = va'),
#  Text(0.2222222222222222, 0.375, 'samples = 0.8%\nvalue = [0.667, 0.333]\nclass = va'),
#  Text(0.26666666666666666, 0.375, 'Age <= 57.0\nsamples = 1.1%\nvalue = [0.75, 0.25]\nclass = va'),
#  Text(0.24444444444444444, 0.2916666666666667, 'samples = 0.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.28888888888888886, 0.2916666666666667, 'samples = 0.8%\nvalue = [0.667, 0.333]\nclass = va'),
#  Text(0.26666666666666666, 0.5416666666666666, 'samples = 0.3%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.3111111111111111, 0.7083333333333334, 'Age <= 34.5\nsamples = 4.4%\nvalue = [0.062, 0.938]\nclass = nao_va'),
#  Text(0.28888888888888886, 0.625, 'samples = 0.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.3333333333333333, 0.625, 'samples = 4.1%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.5513888888888889, 0.7916666666666666, 'Polydipsia_Yes <= 0.5\nsamples = 39.3%\nvalue = [0.846, 0.154]\nclass = va'),
#  Text(0.41388888888888886, 0.7083333333333334, 'Age <= 31.0\nsamples = 34.6%\nvalue = [0.913, 0.087]\nclass = va'),
#  Text(0.39166666666666666, 0.625, 'samples = 6.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.4361111111111111, 0.625, 'Age <= 37.5\nsamples = 28.3%\nvalue = [0.893, 0.107]\nclass = va'),
#  Text(0.35555555555555557, 0.5416666666666666, 'Age <= 36.5\nsamples = 3.8%\nvalue = [0.714, 0.286]\nclass = va'),
#  Text(0.3333333333333333, 0.4583333333333333, 'Age <= 33.0\nsamples = 2.5%\nvalue = [0.889, 0.111]\nclass = va'),
#  Text(0.3111111111111111, 0.375, 'samples = 0.5%\nvalue = [0.5, 0.5]\nclass = va'),
#  Text(0.35555555555555557, 0.375, 'samples = 1.9%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.37777777777777777, 0.4583333333333333, 'samples = 1.4%\nvalue = [0.4, 0.6]\nclass = nao_va'),
#  Text(0.5166666666666667, 0.5416666666666666, 'Age <= 65.5\nsamples = 24.5%\nvalue = [0.921, 0.079]\nclass = va'),
#  Text(0.45555555555555555, 0.4583333333333333, 'sudden weight loss_Yes <= 0.5\nsamples = 22.3%\nvalue = [0.938, 0.062]\nclass = va'),
#  Text(0.4, 0.375, 'Age <= 53.5\nsamples = 19.5%\nvalue = [0.958, 0.042]\nclass = va'),
#  Text(0.35555555555555557, 0.2916666666666667, 'Age <= 42.5\nsamples = 14.0%\nvalue = [0.98, 0.02]\nclass = va'),
#  Text(0.3333333333333333, 0.20833333333333334, 'Age <= 40.0\nsamples = 2.5%\nvalue = [0.889, 0.111]\nclass = va'),
#  Text(0.3111111111111111, 0.125, 'samples = 1.1%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.35555555555555557, 0.125, 'samples = 1.4%\nvalue = [0.8, 0.2]\nclass = va'),
#  Text(0.37777777777777777, 0.20833333333333334, 'samples = 11.5%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.4444444444444444, 0.2916666666666667, 'Age <= 54.5\nsamples = 5.5%\nvalue = [0.9, 0.1]\nclass = va'),
#  Text(0.4222222222222222, 0.20833333333333334, 'samples = 0.5%\nvalue = [0.5, 0.5]\nclass = va'),
#  Text(0.4666666666666667, 0.20833333333333334, 'Age <= 59.0\nsamples = 4.9%\nvalue = [0.944, 0.056]\nclass = va'),
#  Text(0.4444444444444444, 0.125, 'Age <= 57.5\nsamples = 2.7%\nvalue = [0.9, 0.1]\nclass = va'),
#  Text(0.4222222222222222, 0.041666666666666664, 'samples = 1.6%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.4666666666666667, 0.041666666666666664, 'samples = 1.1%\nvalue = [0.75, 0.25]\nclass = va'),
#  Text(0.4888888888888889, 0.125, 'samples = 2.2%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.5111111111111111, 0.375, 'Age <= 41.5\nsamples = 2.7%\nvalue = [0.8, 0.2]\nclass = va'),
#  Text(0.4888888888888889, 0.2916666666666667, 'samples = 1.1%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.5333333333333333, 0.2916666666666667, 'Age <= 49.5\nsamples = 1.6%\nvalue = [0.667, 0.333]\nclass = va'),
#  Text(0.5111111111111111, 0.20833333333333334, 'samples = 0.5%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.5555555555555556, 0.20833333333333334, 'samples = 1.1%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.5777777777777777, 0.4583333333333333, 'Age <= 66.5\nsamples = 2.2%\nvalue = [0.75, 0.25]\nclass = va'),
#  Text(0.5555555555555556, 0.375, 'samples = 0.8%\nvalue = [0.333, 0.667]\nclass = nao_va'),
#  Text(0.6, 0.375, 'samples = 1.4%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.6888888888888889, 0.7083333333333334, 'Age <= 48.5\nsamples = 4.7%\nvalue = [0.353, 0.647]\nclass = nao_va'),
#  Text(0.6222222222222222, 0.625, 'sudden weight loss_Yes <= 0.5\nsamples = 2.2%\nvalue = [0.125, 0.875]\nclass = nao_va'),
#  Text(0.6, 0.5416666666666666, 'samples = 1.4%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.6444444444444445, 0.5416666666666666, 'Age <= 44.0\nsamples = 0.8%\nvalue = [0.333, 0.667]\nclass = nao_va'),
#  Text(0.6222222222222222, 0.4583333333333333, 'samples = 0.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.6666666666666666, 0.4583333333333333, 'samples = 0.5%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.7555555555555555, 0.625, 'sudden weight loss_Yes <= 0.5\nsamples = 2.5%\nvalue = [0.556, 0.444]\nclass = va'),
#  Text(0.7333333333333333, 0.5416666666666666, 'Age <= 62.5\nsamples = 1.9%\nvalue = [0.714, 0.286]\nclass = va'),
#  Text(0.7111111111111111, 0.4583333333333333, 'Age <= 55.5\nsamples = 1.6%\nvalue = [0.833, 0.167]\nclass = va'),
#  Text(0.6888888888888889, 0.375, 'Age <= 52.0\nsamples = 0.5%\nvalue = [0.5, 0.5]\nclass = va'),
#  Text(0.6666666666666666, 0.2916666666666667, 'samples = 0.3%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.7111111111111111, 0.2916666666666667, 'samples = 0.3%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.7333333333333333, 0.375, 'samples = 1.1%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.7555555555555555, 0.4583333333333333, 'samples = 0.3%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.7777777777777778, 0.5416666666666666, 'samples = 0.5%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.9333333333333333, 0.875, 'Polydipsia_Yes <= 0.5\nsamples = 48.6%\nvalue = [0.062, 0.938]\nclass = nao_va'),
#  Text(0.7987847222222222, 0.9166666666666667, '  False'),
#  Text(0.9111111111111111, 0.7916666666666666, 'Age <= 63.5\nsamples = 12.6%\nvalue = [0.239, 0.761]\nclass = nao_va'),
#  Text(0.8666666666666667, 0.7083333333333334, 'Age <= 45.0\nsamples = 8.8%\nvalue = [0.062, 0.938]\nclass = nao_va'),
#  Text(0.8444444444444444, 0.625, 'Age <= 42.0\nsamples = 4.1%\nvalue = [0.133, 0.867]\nclass = nao_va'),
#  Text(0.8222222222222222, 0.5416666666666666, 'samples = 3.6%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.8666666666666667, 0.5416666666666666, 'samples = 0.5%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.8888888888888888, 0.625, 'samples = 4.7%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.9555555555555556, 0.7083333333333334, 'sudden weight loss_Yes <= 0.5\nsamples = 3.8%\nvalue = [0.643, 0.357]\nclass = va'),
#  Text(0.9333333333333333, 0.625, 'samples = 2.5%\nvalue = [1.0, 0.0]\nclass = va'),
#  Text(0.9777777777777777, 0.625, 'samples = 1.4%\nvalue = [0.0, 1.0]\nclass = nao_va'),
#  Text(0.9555555555555556, 0.7916666666666666, 'samples = 36.0%\nvalue = [0.0, 1.0]\nclass = nao_va')]

# %% [markdown]
# ### Teste

# %%
# Faz a predição dos valores para teste
y_pred = clf.predict(X_test)
X_test,y_pred
# Out:
# (     Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes
#  275   72         True          True           False                   False
#  93    40        False          True            True                   False
#  6     57         True          True            True                   False
#  167   41         True          True            True                    True
#  90    45        False         False           False                   False
#  ..   ...          ...           ...             ...                     ...
#  24    58         True          True            True                    True
#  17    67         True         False            True                   False
#  245   30         True         False           False                   False
#  66    30        False          True            True                   False
#  229   47         True         False           False                   False
#
#  [156 rows x 5 columns],
#  array([False,  True,  True,  True,  True,  True,  True, False,  True,
#         False, False,  True,  True, False,  True,  True, False,  True,
#         False,  True,  True,  True,  True,  True, False, False,  True,
#          True, False,  True,  True,  True, False,  True, False,  True,
#          True, False, False, False,  True, False, False,  True, False,
#          True, False,  True, False,  True, False, False,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True, False,  True,  True,  True, False,  True,
#          True,  True,  True,  True, False, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True, False,  True,
#          True,  True,  True,  True, False,  True, False,  True,  True,
#          True, False,  True, False, False,  True,  True, False, False,
#         False, False, False,  True, False, False, False,  True, False,
#         False,  True, False,  True, False,  True,  True,  True,  True,
#          True, False,  True, False,  True,  True,  True,  True, False,
#         False,  True,  True, False,  True,  True, False,  True,  True,
#          True,  True,  True, False,  True, False, False,  True,  True,
#         False,  True, False]))

# %% [markdown]
# ## Avaliação
# ***
#
# **tp** (verdadeiros positivos): casos cassificados parar uma classe corretamente<br>
# **fp** (falsos positivos): casos classificados para uma classe incorretamente<br>
# **tn** (verdadeiros negativos): casos classificados corretamente como falsos<br>
# **fn** (falsos negativos): casos considerados de outra classe mas deveriam ser da classe em questão<br>
# <br>
# **Suporte**: tp + fp, ou seja, o total de casos</br>
# **Precisão**: tp / (tp + fp), ou seja, proporção dos acertos em classificar exemplos positivos <br>
# **Recall**: tp / (tp + fn), ou seja, proporção de acertos entre todas as classes<br>
# **f1-score**: média harmônica entre a Precisão e o Recall<br>
# **Acurácia**: soma do tp de todas as classes dividido pelo número de instâncias do dataset de teste (resulta em uma percentagem).<br>
#
# Uma ótima imagem ilustrativa sobre estas métricas pode ser encontrada na __[Wikipédia](https://pt.wikipedia.org/wiki/Precis%C3%A3o_e_revoca%C3%A7%C3%A3o#/media/Ficheiro:Precis%C3%A3o_e_revoca%C3%A7%C3%A3o.png)__

# %%
from sklearn import metrics #Importando módulo de métricas para avaliação
# Acurácia do modelo, o quanto o classificador está correto?
print("Acurácia:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Acurácia: 0.9230769230769231

# %%
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

print(classification_report(y_test, y_pred, target_names=['Positive','Negative']))
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.88      0.91      0.89        54
#     Negative       0.95      0.93      0.94       102
#
#     accuracy                           0.92       156
#    macro avg       0.91      0.92      0.92       156
# weighted avg       0.92      0.92      0.92       156

# %%
ConfusionMatrixDisplay.from_estimator(
    clf, X_test, y_test, display_labels=['Positive','Negative'], xticks_rotation="vertical"
)
plt.tight_layout()
plt.show()
