# %% [markdown]
# # Experimento: Classificador de Diabetes

# %% [markdown]
# ## Acesso e análise dos dados

# %% [markdown]
# Vamos utilizar a biblioteca https://pandas.pydata.org/ para manipulação dos dados.

# %%
import pandas as pd

# %% [markdown]
# A função __[pd.read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)__ Retorna um Dataframe para manipulação dos dados.

# %%
dataset = pd.read_csv('https://github.com/JojoBR07/Feevale-Jupyter-AI-V1/raw/refs/heads/main/Dataset/diabetes_data_upload.csv'); 
dataset
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 0               No              No     Yes           No             Yes
# 1               No             Yes      No           No              No
# 2               No              No     Yes           No             Yes
# 3              Yes              No     Yes           No             Yes
# 4               No             Yes     Yes          Yes             Yes
# ..             ...             ...     ...          ...             ...
# 515             No              No     Yes           No             Yes
# 516             No              No     Yes          Yes             Yes
# 517             No             Yes      No           No              No
# 518             No             Yes     Yes           No             Yes
# 519             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 0                No              Yes      Yes     Yes  Positive
# 1               Yes               No      Yes      No  Positive
# 2                No              Yes      Yes      No  Positive
# 3                No               No       No      No  Positive
# 4               Yes              Yes      Yes     Yes  Positive
# ..              ...              ...      ...     ...       ...
# 515             Yes               No       No      No  Positive
# 516             Yes               No       No      No  Positive
# 517             Yes              Yes       No     Yes  Positive
# 518              No               No      Yes      No  Negative
# 519              No               No       No      No  Negative
#
# [520 rows x 17 columns]

# %% [markdown]
# <br>
# Veja como os dados carregados foram interpretados ...

# %%
dataset.dtypes
# Out:
# Age                    int64
# Gender                object
# Polyuria              object
# Polydipsia            object
# sudden weight loss    object
# weakness              object
# Polyphagia            object
# Genital thrush        object
# visual blurring       object
# Itching               object
# Irritability          object
# delayed healing       object
# partial paresis       object
# muscle stiffness      object
# Alopecia              object
# Obesity               object
# class                 object
# dtype: object

# %% [markdown]
# <br>
# Uma primeira análise dos dados númericos, como contagem, desvio padrão, entre outros. Apenas os atributos numéricos fazem parte dessa descrição. Lembre que a notação é Americana, portanto o ponto representa vírgula.

# %%
dataset.describe()
# Out:
#               Age
# count  520.000000
# mean    48.028846
# std     12.151466
# min     16.000000
# 25%     39.000000
# 50%     47.500000
# 75%     57.000000
# max     90.000000

# %% [markdown]
# <br>
# Se for necessário, é possível analisar apenas um dos atributos.

# %%
dataset['Age'].mean()
# Out:
# np.float64(48.02884615384615)

# %% [markdown]
# <br>
# Boxplot gerado com base nos dados numéricos do dataset: temperatura e humidade.<br>As colunas dividem os valores em Quartis (P25 = 25%, P50 = 50%, P75 = 75%)

# %%
import matplotlib.pyplot as plt
dataset.boxplot()
plt.show()

# %% [markdown]
# ## Pré-processamento
# ***

# %% [markdown]
# ### Enconding
# Alguns classificadores não aceitam features com valores nominais, então é necessário fazer o enconding em valores binários.
# É o caso do classificador que será empregado mais adiante.<br>
# __[pd.get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)__ converte variáveis categóricas em variáveis binárias. O atributo ***drop_first=True*** produz apenas uma serie / coluna para atributos que possuem apenas dois valores.

# %%
one_hot_dataset = pd.get_dummies(dataset,drop_first=True)
one_hot_dataset
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes  \
# 0     40         True         False            True                   False
# 1     58         True         False           False                   False
# 2     41         True          True           False                   False
# 3     45         True         False           False                    True
# 4     60         True          True            True                    True
# ..   ...          ...           ...             ...                     ...
# 515   39        False          True            True                    True
# 516   48        False          True            True                    True
# 517   58        False          True            True                    True
# 518   32        False         False           False                   False
# 519   42         True         False           False                   False
#
#      weakness_Yes  Polyphagia_Yes  Genital thrush_Yes  visual blurring_Yes  \
# 0            True           False               False                False
# 1            True           False               False                 True
# 2            True            True               False                False
# 3            True            True                True                False
# 4            True            True               False                 True
# ..            ...             ...                 ...                  ...
# 515         False            True               False                False
# 516          True            True               False                False
# 517          True            True               False                 True
# 518          True           False               False                 True
# 519         False           False               False                False
#
#      Itching_Yes  Irritability_Yes  delayed healing_Yes  partial paresis_Yes  \
# 0           True             False                 True                False
# 1          False             False                False                 True
# 2           True             False                 True                False
# 3           True             False                 True                False
# 4           True              True                 True                 True
# ..           ...               ...                  ...                  ...
# 515         True             False                 True                 True
# 516         True              True                 True                 True
# 517        False             False                False                 True
# 518         True             False                 True                False
# 519        False             False                False                False
#
#      muscle stiffness_Yes  Alopecia_Yes  Obesity_Yes  class_Positive
# 0                    True          True         True            True
# 1                   False          True        False            True
# 2                    True          True        False            True
# 3                   False         False        False            True
# 4                    True          True         True            True
# ..                    ...           ...          ...             ...
# 515                 False         False        False            True
# 516                 False         False        False            True
# 517                  True         False         True            True
# 518                 False          True        False           False
# 519                 False         False        False           False
#
# [520 rows x 17 columns]

# %% [markdown]
# <br>
# <i>x<i> representa exemplos de casos (dias) e seus atributos, mas removendo o atributo classe.

# %%
x = one_hot_dataset[one_hot_dataset.columns[:16]] 
x
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes  \
# 0     40         True         False            True                   False
# 1     58         True         False           False                   False
# 2     41         True          True           False                   False
# 3     45         True         False           False                    True
# 4     60         True          True            True                    True
# ..   ...          ...           ...             ...                     ...
# 515   39        False          True            True                    True
# 516   48        False          True            True                    True
# 517   58        False          True            True                    True
# 518   32        False         False           False                   False
# 519   42         True         False           False                   False
#
#      weakness_Yes  Polyphagia_Yes  Genital thrush_Yes  visual blurring_Yes  \
# 0            True           False               False                False
# 1            True           False               False                 True
# 2            True            True               False                False
# 3            True            True                True                False
# 4            True            True               False                 True
# ..            ...             ...                 ...                  ...
# 515         False            True               False                False
# 516          True            True               False                False
# 517          True            True               False                 True
# 518          True           False               False                 True
# 519         False           False               False                False
#
#      Itching_Yes  Irritability_Yes  delayed healing_Yes  partial paresis_Yes  \
# 0           True             False                 True                False
# 1          False             False                False                 True
# 2           True             False                 True                False
# 3           True             False                 True                False
# 4           True              True                 True                 True
# ..           ...               ...                  ...                  ...
# 515         True             False                 True                 True
# 516         True              True                 True                 True
# 517        False             False                False                 True
# 518         True             False                 True                False
# 519        False             False                False                False
#
#      muscle stiffness_Yes  Alopecia_Yes  Obesity_Yes
# 0                    True          True         True
# 1                   False          True        False
# 2                    True          True        False
# 3                   False         False        False
# 4                    True          True         True
# ..                    ...           ...          ...
# 515                 False         False        False
# 516                 False         False        False
# 517                  True         False         True
# 518                 False          True        False
# 519                 False         False        False
#
# [520 rows x 16 columns]

# %% [markdown]
# <br><i>Y</i> representa a série dos valores classe de cada exemplo.

# %%
y = one_hot_dataset['class_Positive'] 
y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 515     True
# 516     True
# 517     True
# 518    False
# 519    False
# Name: class_Positive, Length: 520, dtype: bool

# %% [markdown]
# ### Separação em Treino e Teste
# A função __[train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)__ extrai um conjunto aleatório de 70% para treino and 30% para teste.
# Uma questão interessante é utilizar o parâmetro *random_state* com um valor fixo inteiro, como por exemplo __[42](https://en.wikipedia.org/wiki/Phrases_from_The_Hitchhiker%27s_Guide_to_the_Galaxy#The_Answer_to_the_Ultimate_Question_of_Life,_the_Universe,_and_Everything_is_42)__. Desta forma, durante o desenvolvimento, a saída do split será sempre a mesma, de forma que é possível avaliar o pipe e seus resultados de forma contínua com os mesmos dados. Quando o pipe estiver em produção, trocamos o parâmetro *random_state* para *None*.

# %%
# Importando biblioteca de separação de treino / teste
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=42)

# %%
x_train
# Out:
#      Age  Gender_Male  Polyuria_Yes  Polydipsia_Yes  sudden weight loss_Yes  \
# 225   29         True         False           False                   False
# 94    36        False          True            True                   False
# 462   57         True         False           False                   False
# 284   72         True          True           False                   False
# 23    48         True         False            True                    True
# ..   ...          ...           ...             ...                     ...
# 71    35        False         False            True                    True
# 106   58         True         False            True                    True
# 270   40        False          True            True                    True
# 435   57         True          True            True                    True
# 102   90        False         False            True                    True
#
#      weakness_Yes  Polyphagia_Yes  Genital thrush_Yes  visual blurring_Yes  \
# 225          True           False               False                False
# 94           True            True               False                 True
# 462         False            True               False                 True
# 284         False            True               False                 True
# 23           True           False               False                 True
# ..            ...             ...                 ...                  ...
# 71           True           False               False                False
# 106          True            True               False                 True
# 270          True           False               False                 True
# 435          True            True               False                 True
# 102         False           False                True                 True
#
#      Itching_Yes  Irritability_Yes  delayed healing_Yes  partial paresis_Yes  \
# 225        False             False                False                False
# 94          True             False                 True                 True
# 462        False             False                False                False
# 284         True             False                 True                 True
# 23          True              True                 True                False
# ..           ...               ...                  ...                  ...
# 71          True             False                 True                 True
# 106         True             False                False                 True
# 270        False             False                 True                 True
# 435        False             False                False                 True
# 102         True             False                False                False
#
#      muscle stiffness_Yes  Alopecia_Yes  Obesity_Yes
# 225                 False         False        False
# 94                  False         False        False
# 462                  True         False        False
# 284                  True          True        False
# 23                  False         False        False
# ..                    ...           ...          ...
# 71                   True         False        False
# 106                 False          True         True
# 270                  True         False        False
# 435                 False         False        False
# 102                  True          True        False
#
# [364 rows x 16 columns]

# %% [markdown]
# ### Armazenamento dos Conjuntos de Dados em Arquivos
# A função **to_csv()** permite que possa ser salvo determinado consulto em arquivo CSV.
# O parâmetro *index=False* no método **to_csv()** serve para não salvar a coluna de índice do DataFrame no arquivo CSV.

# %% [markdown]
# <br><i>os.makedirs</i> Cria uma pasta chamada 'Files' se ainda não existir.

# %%
import os
os.makedirs('Files', exist_ok=True)

# %% [markdown]
# <br>Armazenamento dos conjuntos de treino, teste e séries no diretório 'Files'

# %%
x_train.to_csv('Files/x_train.csv', index=False)
x_test.to_csv('Files/x_test.csv', index=False)
y_train.to_csv('Files/y_train.csv', index=False)
y_test.to_csv('Files/y_test.csv', index=False)

x.to_csv('Files/series_x.csv', index=False)
y.to_csv('Files/series_y.csv', index=False)

# %% [markdown]
# <br>Lista arquivos do diretório 'Files'

# %%
os.listdir('Files')
# Out:
# ['.ipynb_checkpoints',
#  'predicted_y.csv',
#  'series_x.csv',
#  'series_y.csv',
#  'x_test.csv',
#  'x_train.csv',
#  'y_test.csv',
#  'y_train.csv']
